# %%
import json
import scipy.sparse as sp
import numpy as np
import matplotlib.pyplot as plt
from utils.spatial_multipliers import spatial_multipliers

# %%
addtional_funding = (2060 + 12360 + 12360 + 10300) * 2 / 3
bumping_up_hiwis = (4 / 3 * 24 / 20 - 1) * addtional_funding / 2
1000 + 1000 + 3500 + 500 + 300 + 1440 + 7400 + 5000 + 2000 + 1000 + 2500 + 200 + 600 + 240 + 200 + 700
# Out:
# 27580

# %%
data = np.load("../../data/md_h2.npz", allow_pickle=True)
R = data["R"]
R_dist = np.linalg.norm(R[:, 0, :] - R[:, 1, :], axis=-1)
plt.plot(R_dist)

# %%
data_r = np.repeat(np.concatenate([[0], data["N"][:-1]]), data["N"])
np.repeat(data_r, data_repeated)
# Out:
# array([0, 0, 0, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2])

# %%
x = np.array([1.8343, -1.8343, 0.6642, -0.6642, -0.5039, 0.5039, -1.6810, 1.6810])
y = np.array([2.6444, -2.6444, 0.3772, -0.3772, -1.8966, 1.8966, -3.7262, 3.7262])
plt.axis("equal")
plt.scatter(x, y)
